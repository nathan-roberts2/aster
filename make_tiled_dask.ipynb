# %% [markdown]
# ## Transform ASTER Level-2 Data into Tiled Northup Product
#
# This notebook provides a protoype function to convert the Level-2 V4 ASTER Products from their archieved rotated map orientation trasnformation to a northup transformation tiled product based upon the HLS (MGRS) Grid.
#
# The goals include:
# 1. Convert Rotated ASTER Data to Northup tiled product to support potential time series and mosaicing
# 2. Preserve input paramters (height, wideth, crs, pixel centers) in order to preserve alignment between northup
# 3. Write transformed tifs as some output that can be viewed in a GIS to compare with input data
#
# MGRS Grid is Read in from the [HLS Website](https://hls.gsfc.nasa.gov/products-description/tiling-system/)
#
# As of 12/12/25 this method was tested on AST_07 for one acquisition all bands. Still need to try with the other Level-2 Products (Visable: AST_09, AST_09X, AST_07X) and (Thermal:  AST_09T, AST_08, AST_05).
#
# To do:
#
# 1. Instead of writing outputs save in memory and process somehow into some usecase

# %%
import geopandas as gpd
import os
import rioxarray as rxr
import earthaccess
from osgeo import gdal
import pandas as pd
import fiona
from rasterio.transform import from_origin
from rasterio.warp import Resampling
import numpy as np
from shapely.geometry import box
import matplotlib.pyplot as plt
import xarray as xr
import requests
import tempfile
import rasterio
import earthaccess
from dask.distributed import Client, LocalCluster
import dask.distributed

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
fiona.supported_drivers['KML'] = 'rw'

# %%
#Set working directory for outputs
os.chdir(r'C:\Users\nroberts\aster\data')

#Link to MGRS Grid KML
mgrs_path  = 'S2A_OPER_GIP_TILPAR_MPC__20151209T095117_V20150622T000000_21000101T000000_B00.kml'

#aoi
aoi = gpd.read_file('railroad_valley.geojson')
bbox = tuple(list(aoi.total_bounds))

# %%
bbox = tuple(list(aoi.total_bounds))
bbox
# Out:
# (np.float64(-115.89358304108943),
#  np.float64(38.31559085515974),
#  np.float64(-115.33911006153537),
#  np.float64(38.5826536407757))

# %%
temporal = ("2000-01-05T00:00:00", "2000-12-31T23:59:59")

# %%
results = earthaccess.search_data(
    concept_id='C3306877498-LPCLOUD',
    bounding_box=bbox,
    temporal=temporal,
    provider='LPCLOUD',
    cloud_cover=(0,5),
)
print(len(results))

pd.json_normalize(results)
# Out:
# 10
#         size meta.concept-type      meta.concept-id  meta.revision-id  \
# 0  82.159832           granule  G3894750374-LPCLOUD                 1
# 1  83.580978           granule  G3894860802-LPCLOUD                 1
# 2  85.739986           granule  G3381036200-LPCLOUD                 2
# 3  86.793748           granule  G3381036159-LPCLOUD                 2
# 4  88.540433           granule  G3381120992-LPCLOUD                 2
# 5  88.491818           granule  G3382871090-LPCLOUD                 2
# 6  87.318604           granule  G3383595983-LPCLOUD                 2
# 7  85.725320           granule  G3383912667-LPCLOUD                 2
# 8  85.922054           granule  G3383901960-LPCLOUD                 2
# 9  87.089227           granule  G3385537013-LPCLOUD                 2
#
#                             meta.native-id meta.collection-concept-id  \
# 0  AST_07_00405012000190040_20251203152300        C3306877498-LPCLOUD
# 1  AST_07_00405012000190049_20251203163451        C3306877498-LPCLOUD
# 2  AST_07_00406022000185958_20250124215439        C3306877498-LPCLOUD
# 3  AST_07_00406022000190006_20250124215740        C3306877498-LPCLOUD
# 4  AST_07_00406112000185353_20250125001226        C3306877498-LPCLOUD
# 5  AST_07_00407292000185301_20250126144311        C3306877498-LPCLOUD
# 6  AST_07_00408142000185318_20250127055431        C3306877498-LPCLOUD
# 7  AST_07_00408212000185930_20250127132231        C3306877498-LPCLOUD
# 8  AST_07_00408212000185939_20250127132136        C3306877498-LPCLOUD
# 9  AST_07_00410012000185240_20250129021625        C3306877498-LPCLOUD
#
#   meta.provider-id                        meta.format  \
# 0          LPCLOUD  application/vnd.nasa.cmr.umm+json
# 1          LPCLOUD  application/vnd.nasa.cmr.umm+json
# 2          LPCLOUD  application/vnd.nasa.cmr.umm+json
# 3          LPCLOUD  application/vnd.nasa.cmr.umm+json
# 4          LPCLOUD  application/vnd.nasa.cmr.umm+json
# 5          LPCLOUD  application/vnd.nasa.cmr.umm+json
# 6          LPCLOUD  application/vnd.nasa.cmr.umm+json
# 7          LPCLOUD  application/vnd.nasa.cmr.umm+json
# 8          LPCLOUD  application/vnd.nasa.cmr.umm+json
# 9          LPCLOUD  application/vnd.nasa.cmr.umm+json
#
#          meta.revision-date umm.TemporalExtent.SingleDateTime  \
# 0  2025-12-03T22:40:26.017Z        2000-05-01T19:00:40.72200Z
# 1  2025-12-03T23:39:26.102Z        2000-05-01T19:00:49.55800Z
# 2  2025-04-18T03:24:09.328Z       2000-06-02T18:59:58.142000Z
# 3  2025-04-18T03:19:09.975Z       2000-06-02T19:00:06.982000Z
# 4  2025-04-18T05:22:12.151Z       2000-06-11T18:53:53.850000Z
# 5  2025-04-19T05:07:09.204Z       2000-07-29T18:53:01.605000Z
# 6  2025-04-19T11:43:07.642Z       2000-08-14T18:53:18.235000Z
# 7  2025-04-19T15:02:09.859Z       2000-08-21T18:59:30.285000Z
# 8  2025-04-19T15:30:06.388Z       2000-08-21T18:59:39.123000Z
# 9  2025-04-20T07:07:09.433Z       2000-10-01T18:52:40.953000Z
#
#                              umm.GranuleUR  \
# 0  AST_07_00405012000190040_20251203152300
# 1  AST_07_00405012000190049_20251203163451
# 2  AST_07_00406022000185958_20250124215439
# 3  AST_07_00406022000190006_20250124215740
# 4  AST_07_00406112000185353_20250125001226
# 5  AST_07_00407292000185301_20250126144311
# 6  AST_07_00408142000185318_20250127055431
# 7  AST_07_00408212000185930_20250127132231
# 8  AST_07_00408212000185939_20250127132136
# 9  AST_07_00410012000185240_20250129021625
#
#                             umm.AdditionalAttributes  \
# 0  [{'Name': 'Band01LocalGranuleID', 'Values': ['...
# 1  [{'Name': 'Band01LocalGranuleID', 'Values': ['...
# 2  [{'Name': 'Band01LocalGranuleID', 'Values': ['...
# 3  [{'Name': 'Band01LocalGranuleID', 'Values': ['...
# 4  [{'Name': 'Band01LocalGranuleID', 'Values': ['...
# 5  [{'Name': 'Band01LocalGranuleID', 'Values': ['...
# 6  [{'Name': 'Band01LocalGranuleID', 'Values': ['...
# 7  [{'Name': 'Band01LocalGranuleID', 'Values': ['...
# 8  [{'Name': 'Band01LocalGranuleID', 'Values': ['...
# 9  [{'Name': 'Band01LocalGranuleID', 'Values': ['...
#
#                               umm.MeasuredParameters  \
# 0  [{'ParameterName': 'Surface Reflectance - VNIR...
# 1  [{'ParameterName': 'Surface Reflectance - VNIR...
# 2  [{'ParameterName': 'Surface Reflectance - VNIR...
# 3  [{'ParameterName': 'Surface Reflectance - VNIR...
# 4  [{'ParameterName': 'Surface Reflectance - VNIR...
# 5  [{'ParameterName': 'Surface Reflectance - VNIR...
# 6  [{'ParameterName': 'Surface Reflectance - VNIR...
# 7  [{'ParameterName': 'Surface Reflectance - VNIR...
# 8  [{'ParameterName': 'Surface Reflectance - VNIR...
# 9  [{'ParameterName': 'Surface Reflectance - VNIR...
#
#   umm.SpatialExtent.HorizontalSpatialDomain.Geometry.GPolygons  \
# 0  [{'Boundary': {'Points': [{'Longitude': -116.3...
# 1  [{'Boundary': {'Points': [{'Longitude': -116.4...
# 2  [{'Boundary': {'Points': [{'Longitude': -116.2...
# 3  [{'Boundary': {'Points': [{'Longitude': -116.3...
# 4  [{'Boundary': {'Points': [{'Longitude': -115.7...
# 5  [{'Boundary': {'Points': [{'Longitude': -115.9...
# 6  [{'Boundary': {'Points': [{'Longitude': -115.6...
# 7  [{'Boundary': {'Points': [{'Longitude': -116.3...
# 8  [{'Boundary': {'Points': [{'Longitude': -116.4...
# 9  [{'Boundary': {'Points': [{'Longitude': -116.4...
#
#                                    umm.ProviderDates  \
# 0  [{'Date': '2025-12-03T21:40:53.000Z', 'Type': ...
# 1  [{'Date': '2025-12-03T22:49:28.000Z', 'Type': ...
# 2  [{'Date': '2025-01-25T04:12:23.000Z', 'Type': ...
# 3  [{'Date': '2025-01-25T04:14:26.000Z', 'Type': ...
# 4  [{'Date': '2025-01-25T06:26:53.000Z', 'Type': ...
# 5  [{'Date': '2025-01-26T20:55:07.000Z', 'Type': ...
# 6  [{'Date': '2025-01-27T12:09:46.000Z', 'Type': ...
# 7  [{'Date': '2025-01-27T19:40:06.000Z', 'Type': ...
# 8  [{'Date': '2025-01-27T19:36:01.000Z', 'Type': ...
# 9  [{'Date': '2025-01-29T08:28:16.000Z', 'Type': ...
#
#   umm.CollectionReference.ShortName umm.CollectionReference.Version  \
# 0                            AST_07                             004
# 1                            AST_07                             004
# 2                            AST_07                             004
# 3                            AST_07                             004
# 4                            AST_07                             004
# 5                            AST_07                             004
# 6                            AST_07                             004
# 7                            AST_07                             004
# 8                            AST_07                             004
# 9                            AST_07                             004
#
#   umm.PGEVersionClass.PGEVersion  \
# 0                 Correct_VS:3.4
# 1                 Correct_VS:3.4
# 2                 Correct_VS:3.4
# 3                 Correct_VS:3.4
# 4                 Correct_VS:3.4
# 5                 Correct_VS:3.4
# 6                 Correct_VS:3.4
# 7                 Correct_VS:3.4
# 8                 Correct_VS:3.4
# 9                 Correct_VS:3.4
#
#                                      umm.RelatedUrls  umm.CloudCover  \
# 0  [{'URL': 'https://doi.org/10.5067/ASTER/AST_07...               0
# 1  [{'URL': 'https://doi.org/10.5067/ASTER/AST_07...               0
# 2  [{'URL': 'https://doi.org/10.5067/ASTER/AST_07...               2
# 3  [{'URL': 'https://doi.org/10.5067/ASTER/AST_07...               2
# 4  [{'URL': 'https://doi.org/10.5067/ASTER/AST_07...               2
# 5  [{'URL': 'https://doi.org/10.5067/ASTER/AST_07...               1
# 6  [{'URL': 'https://doi.org/10.5067/ASTER/AST_07...               0
# 7  [{'URL': 'https://doi.org/10.5067/ASTER/AST_07...               0
# 8  [{'URL': 'https://doi.org/10.5067/ASTER/AST_07...               0
# 9  [{'URL': 'https://doi.org/10.5067/ASTER/AST_07...               0
#
#                                    umm.InputGranules  \
# 0  [AST_07_00405012000190040_20251203152300.hdf, ...
# 1  [AST_07_00405012000190049_20251203163451.hdf, ...
# 2  [AST_07_00406022000185958_20250124215439.hdf, ...
# 3  [AST_07_00406022000190006_20250124215740.hdf, ...
# 4  [AST_07_00406112000185353_20250125001226.hdf, ...
# 5  [AST_07_00407292000185301_20250126144311.hdf, ...
# 6  [AST_07_00408142000185318_20250127055431.hdf, ...
# 7  [AST_07_00408212000185930_20250127132231.hdf, ...
# 8  [AST_07_00408212000185939_20250127132136.hdf, ...
# 9  [AST_07_00410012000185240_20250129021625.hdf, ...
#
#                          umm.DataGranule.Identifiers  \
# 0  [{'Identifier': 'AST_07_00405012000190040_2025...
# 1  [{'Identifier': 'AST_07_00405012000190049_2025...
# 2  [{'Identifier': 'AST_07_00406022000185958_2025...
# 3  [{'Identifier': 'AST_07_00406022000190006_2025...
# 4  [{'Identifier': 'AST_07_00406112000185353_2025...
# 5  [{'Identifier': 'AST_07_00407292000185301_2025...
# 6  [{'Identifier': 'AST_07_00408142000185318_2025...
# 7  [{'Identifier': 'AST_07_00408212000185930_2025...
# 8  [{'Identifier': 'AST_07_00408212000185939_2025...
# 9  [{'Identifier': 'AST_07_00410012000185240_2025...
#
#   umm.DataGranule.DayNightFlag umm.DataGranule.ProductionDateTime  \
# 0                          Day           2025-12-03T21:40:53.000Z
# 1                          Day           2025-12-03T22:49:28.000Z
# 2                          Day           2025-01-25T04:12:23.000Z
# 3                          Day           2025-01-25T04:14:26.000Z
# 4                          Day           2025-01-25T06:26:53.000Z
# 5                          Day           2025-01-26T20:55:07.000Z
# 6                          Day           2025-01-27T12:09:46.000Z
# 7                          Day           2025-01-27T19:40:06.000Z
# 8                          Day           2025-01-27T19:36:01.000Z
# 9                          Day           2025-01-29T08:28:16.000Z
#
#    umm.DataGranule.ArchiveAndDistributionInformation  \
# 0  [{'Name': 'AST_07_00405012000190040_2025120315...
# 1  [{'Name': 'AST_07_00405012000190049_2025120316...
# 2  [{'Name': 'AST_07_00406022000185958_2025012421...
# 3  [{'Name': 'AST_07_00406022000190006_2025012421...
# 4  [{'Name': 'AST_07_00406112000185353_2025012500...
# 5  [{'Name': 'AST_07_00407292000185301_2025012614...
# 6  [{'Name': 'AST_07_00408142000185318_2025012705...
# 7  [{'Name': 'AST_07_00408212000185930_2025012713...
# 8  [{'Name': 'AST_07_00408212000185939_2025012713...
# 9  [{'Name': 'AST_07_00410012000185240_2025012902...
#
#                                        umm.Platforms  \
# 0  [{'ShortName': 'TERRA', 'Instruments': [{'Shor...
# 1  [{'ShortName': 'TERRA', 'Instruments': [{'Shor...
# 2  [{'ShortName': 'TERRA', 'Instruments': [{'Shor...
# 3  [{'ShortName': 'TERRA', 'Instruments': [{'Shor...
# 4  [{'ShortName': 'TERRA', 'Instruments': [{'Shor...
# 5  [{'ShortName': 'TERRA', 'Instruments': [{'Shor...
# 6  [{'ShortName': 'TERRA', 'Instruments': [{'Shor...
# 7  [{'ShortName': 'TERRA', 'Instruments': [{'Shor...
# 8  [{'ShortName': 'TERRA', 'Instruments': [{'Shor...
# 9  [{'ShortName': 'TERRA', 'Instruments': [{'Shor...
#
#                        umm.MetadataSpecification.URL  \
# 0  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6
# 1  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6
# 2  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6
# 3  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6
# 4  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6
# 5  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6
# 6  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6
# 7  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6
# 8  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6
# 9  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6
#
#   umm.MetadataSpecification.Name umm.MetadataSpecification.Version
# 0                          UMM-G                             1.6.6
# 1                          UMM-G                             1.6.6
# 2                          UMM-G                             1.6.6
# 3                          UMM-G                             1.6.6
# 4                          UMM-G                             1.6.6
# 5                          UMM-G                             1.6.6
# 6                          UMM-G                             1.6.6
# 7                          UMM-G                             1.6.6
# 8                          UMM-G                             1.6.6
# 9                          UMM-G                             1.6.6

# %%
urls = [granule.data_links() for granule in results]
urls = [item for sublist in urls for item in sublist]
urls
# Out:
# ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000190040_20251203152300/AST_07_00405012000190040_20251203152301_SRF_SWIR_B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000190040_20251203152300/AST_07_00405012000190040_20251203152301_SRF_SWIR_B05.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000190040_20251203152300/AST_07_00405012000190040_20251203152301_SRF_SWIR_B06.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000190040_20251203152300/AST_07_00405012000190040_20251203152301_SRF_SWIR_B07.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000190040_20251203152300/AST_07_00405012000190040_20251203152301_SRF_SWIR_B08.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000190040_20251203152300/AST_07_00405012000190040_20251203152301_SRF_SWIR_B09.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000190040_20251203152300/AST_07_00405012000190040_20251203152300_SRF_VNIR_B01.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000190040_20251203152300/AST_07_00405012000190040_20251203152300_SRF_VNIR_B02.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000190040_20251203152300/AST_07_00405012000190040_20251203152300_SRF_VNIR_B03N.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000190040_20251203152300/AST_07_00405012000190040_20251203152301_SRF_SWIR_QA_DataPlane.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000190040_20251203152300/AST_07_00405012000190040_20251203152301_SRF_SWIR_QA_DataPlane2.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000190040_20251203152300/AST_07_00405012000190040_20251203152300_SRF_VNIR_QA_DataPlane.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000190040_20251203152300/AST_07_00405012000190040_20251203152300_SRF_VNIR_QA_DataPlane2.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000190049_20251203163451/AST_07_00405012000190049_20251203163452_SRF_SWIR_B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000190049_20251203163451/AST_07_00405012000190049_20251203163452_SRF_SWIR_B05.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000
tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00410012000185240_20250129021625/AST_07_00410012000185240_20250129021625_SRF_VNIR_B03N.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00410012000185240_20250129021625/AST_07_00410012000185240_20250129021626_SRF_SWIR_QA_DataPlane.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00410012000185240_20250129021625/AST_07_00410012000185240_20250129021626_SRF_SWIR_QA_DataPlane2.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00410012000185240_20250129021625/AST_07_00410012000185240_20250129021625_SRF_VNIR_QA_DataPlane.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00410012000185240_20250129021625/AST_07_00410012000185240_20250129021625_SRF_VNIR_QA_DataPlane2.tif']

# %%
def setup_dask_environment():
    """
    Passes RIO environment variables to dask workers for authentication.
    """
    import os
    import rasterio

    global env
    env = rasterio.Env(
        GDAL_DISABLE_READDIR_ON_OPEN="EMPTY_DIR",
        GDAL_HTTP_COOKIEFILE=os.path.expanduser("~/cookies.txt"),
        GDAL_HTTP_COOKIEJAR=os.path.expanduser("~/cookies.txt"),
        GDAL_HTTP_MAX_RETRY="10",
        GDAL_HTTP_RETRY_DELAY="0.5",
    )
    env.__enter__()

# %%
#Read in MGRS (HLS) Grid from the HLS Website and return as geopandas dataframe
def load_mgrs(mgrs_path, aoi):

    #response = requests.get(mgrs_url)

    #with tempfile.NamedTemporaryFile(suffix='.kml', delete=False) as tmp:
    #    tmp.write(response.content)
    #    tmp_path = tmp.name

    mgrs_grid = gpd.read_file(mgrs_path, driver = 'KML')
    mgrs_grid = mgrs_grid.set_crs('EPSG:4326')
    mgrs_grid = gpd.sjoin(mgrs_grid, aoi, predicate='intersects')
    mgrs_grid = mgrs_grid.drop(['index_right'], axis=1)
    return mgrs_grid

# %%
#Read in Source (Rotated) Data and return required variables
def read_rotated(input_file, 
                nodata = 0):
    
    rotated = rxr.open_rasterio(input_file, mask_and_scale=False, chunks='auto')
    rotated = rotated.rio.write_nodata(nodata)
    rotated_transform = rotated.rio.transform()
    rotated_crs = rotated.rio.crs

    #return rotated xarray, rotated transformation, rotated_crs, rotated_bounds

    return rotated, rotated_transform, rotated_crs

# %%
"""Calculate true bounds of the rotated tif, it does not work to just use the bounds of the rotated
data as GIS flips the bounds north because data is assumed not to be rotated by GIS and by
geopandas
"""
def get_rotated_bounds(rotated, rotated_crs):
    rotated_bounds = rasterio.transform.array_bounds(rotated.rio.width, rotated.rio.height, rotated.rio.transform())
    minx, miny, maxx, maxy = rotated_bounds
    geom = box(minx, miny, maxx, maxy) 
    
    gdf_bounds = gpd.GeoDataFrame({'geometry': [geom]}, crs = rotated_crs)
    gdf_bounds = gdf_bounds.to_crs('epsg:4326')

    return gdf_bounds

# %%
#Get intesecting MGRS tiles from MGRS Grid and return the tile bounds
def get_mgrs_tile(mgrs_grid, gdf_bounds, rotated_crs):
    mgrs_tile = gpd.sjoin(mgrs_grid, gdf_bounds, predicate='intersects')



    mgrs_tile = mgrs_tile.to_crs(rotated_crs)
    mgrs_tile['minx'] = mgrs_tile.bounds['minx']
    mgrs_tile['miny'] = mgrs_tile.bounds['miny']
    mgrs_tile['maxx'] = mgrs_tile.bounds['maxx']
    mgrs_tile['maxy'] = mgrs_tile.bounds['maxy']
    
    return mgrs_tile

# %%
"""
This is where we create the northup tiled products.

1. Iterate over intersecting tiles geodataframe so we get a tile for each part of the source tif
covered.
2. Get bounds for the bounding box of the MGRS Tile.
3. Calculate the X, Y Resolution we can't just use the resolution from the rotated transformation
because it is several decimal points different then the published resolution of 15, 30, and 90 meters
for VNIR, SWIR and TIR.
4. Calculate shape height.
5. Create new transformation for north up
6. Reproject rotated data using north up transform and with and height for mgrs_tiled data
7. Write out ouputs
8. Add coords that might be useful to create a xarray dataset later (Band Name and MGRS Tile ID)
"""
def make_tiled(rotated, rotated_transform, mgrs_tile, rotated_crs, tif, aoi):


    for i, row in mgrs_tile.iterrows():
   
        minx = row['minx']
        maxy = row['maxy']
        maxx = row['maxx']
        miny = row['miny']


    
        res_x = np.sqrt(rotated_transform.a**2 + rotated_transform.b**2)
        res_y = np.sqrt(rotated_transform.d**2 + rotated_transform.e**2)

        out_with = int((maxx - minx)/res_x)
        out_height = int((maxy - miny)/res_y)

        north_up = from_origin(minx, maxy, res_x, res_y)

        mgrs_aster = rotated.rio.reproject(rotated.rio.crs, shape = (out_height, out_with), transform = north_up, resampling = Resampling.bilinear)
        tname = row['Name']
        output_file = tif.split('/')[6][:-4]
        if 'QA' in output_file:
            band_name = '_'.join(output_file.split('_')[5:8])
        else:
            band_name = '_'.join(output_file.split('_')[5:7])
        
        mgrs_aster = mgrs_aster.squeeze('band', drop = True)
        mgrs_aster = mgrs_aster.rename(band_name)
        mgrs_aster = mgrs_aster.assign_coords(tile_id = tname)

        aoi_reproj = aoi.to_crs(mgrs_aster.rio.crs)
        clipped = mgrs_aster.rio.clip(aoi_reproj.geometry.values, aoi_reproj.crs, all_touched=True)
        clipped.rio.to_raster(f'{output_file}_{tname}_{'bounds'}.tif')

    return clipped

# %%
# Initialize Dask Cluster
client = dask.distributed.Client()

# Setup Dask Environment (GDAL Configs)
client.run(setup_dask_environment)

client
# Out:
# <Client: 'tcp://127.0.0.1:54496' processes=4 threads=12, memory=31.66 GiB>

# %%
mgrs_grid = load_mgrs(mgrs_path, aoi)

def process_file(tif, mgrs_grid, aoi):
    rotated, rotated_transform, rotated_crs, = read_rotated(tif)
    rotated_bounds = get_rotated_bounds(rotated, rotated_crs)
    mgrs_tile = get_mgrs_tile(mgrs_grid, rotated_bounds, rotated_crs)

    make_tiled(rotated, rotated_transform, mgrs_tile, rotated_crs,tif, aoi)

lazy_results = [dask.delayed(process_file)(f, mgrs_grid, aoi) for f in urls]

# Compute the results in parallel
results = dask.compute(*lazy_results)
# Out:
# c:\Users\nroberts\AppData\Local\miniforge3\envs\lpdaac\Lib\site-packages\pyogrio\geopandas.py:275: UserWarning: More than one layer found in 'S2A_OPER_GIP_TILPAR_MPC__20151209T095117_V20150622T000000_21000101T000000_B00.kml': 'Features' (default), 'Info'. Specify layer parameter to avoid this warning.
#   result = read_func(

# %%
client.close()
