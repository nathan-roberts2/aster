# %%
import os
import earthaccess
from dask.distributed import Client, LocalCluster
from osgeo import gdal
import rioxarray as rxr
import dask.config

# %%
auth = earthaccess.login(persist=True)

token = auth.token['access_token']

cluster = LocalCluster(
    processes=True,
    env={'ACCESS_TOKEN':token
         }
)

client = Client(cluster)
client

# %%
cluster = LocalCluster(
    processes=True,
    env={'ACCESS_TOKEN':token
         }
)

Client = Client(cluster)
# Out:
# c:\Users\nroberts\AppData\Local\miniforge3\envs\lpdaac\Lib\site-packages\distributed\node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 58526 instead
#   warnings.warn(

# %%
Client
# Out:
# <Client: 'tcp://127.0.0.1:58527' processes=4 threads=12, memory=31.66 GiB>

# %%
def check ():
    import os
    return os.environ.get('ACCESS_TOKEN')

Client.run(check)
# Out:
# {'tcp://127.0.0.1:58546': 'eyJ0eXAiOiJKV1QiLCJvcmlnaW4iOiJFYXJ0aGRhdGEgTG9naW4iLCJzaWciOiJlZGxqd3RwdWJrZXlfb3BzIiwiYWxnIjoiUlMyNTYifQ.eyJ0eXBlIjoiVXNlciIsInVpZCI6Im5yb2JlcnRzODIiLCJleHAiOjE3Njg2MDAxMTIsImlhdCI6MTc2MzQxNjExMiwiaXNzIjoiaHR0cHM6Ly91cnMuZWFydGhkYXRhLm5hc2EuZ292IiwiaWRlbnRpdHlfcHJvdmlkZXIiOiJlZGxfb3BzIiwiYWNyIjoiZWRsIiwiYXNzdXJhbmNlX2xldmVsIjozfQ.FyryMzsqeejoeLmQOt0w31yRw03F6BAYga9FbQ5-NAXazzjxMx0-I5tWoOBeAd_rR8UL2JKX3BdzO6pH2xlAflULoGpDp4MXODETD1_uA5_NDsgNk4_mvoXAkeSRiggeclE3WFJ55OrRG7h1EQW_M6OhzUjnmYniwb3rDImnSy8w8T9ZeX07ZJXKRDRa0upqJZTHbiBEebVGvnAXkPISE856iXodOAWAIchFAP5i5llw7WRqESdO59KZ17Rth8rQfTSvR5lhswLK-jL73GSoA6-mxkwMdywX6wCJ8vAKtqOCEZU-Uxe9pktUsRhRhui0NDSY7GA7sx6t4w0LyIDHzQ',
# ...

# %%
os.environ['EARTHDATA_TOKEN']  = auth.token['access_token']

# %%
token = auth.token['access_token']

# %%
auth = earthaccess.login(strategy="environment")

# %%
client = Client()

# %%
client

# %%
gdal.SetConfigOption('GDAL_HTTP_COOKIEFILE','~/cookies.txt')
gdal.SetConfigOption('GDAL_HTTP_COOKIEJAR', '~/cookies.txt')
gdal.SetConfigOption('GDAL_DISABLE_READDIR_ON_OPEN','EMPTY_DIR')
gdal.SetConfigOption('CPL_VSIL_CURL_ALLOWED_EXTENSIONS','TIF')
gdal.SetConfigOption('GDAL_HTTP_UNSAFESSL', 'YES')
gdal.SetConfigOption('GDAL_HTTP_MAX_RETRY', '10')
gdal.SetConfigOption('GDAL_HTTP_RETRY_DELAY', '0.5')

# %%
urls = [' https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000190040_20251203152300/AST_07_00405012000190040_20251203152301_SRF_SWIR_B04.tif',
  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/AST_07.004/AST_07_00405012000190040_20251203152300/AST_07_00405012000190040_20251203152301_SRF_SWIR_B05.tif']

# %%
for item in urls:
    ds = rxr.open_rasterio(item, mask_and_scale=False, chunks={'x':1024, 'y':1024})

# %%
ds
# Out:
# <xarray.DataArray (band: 1, y: 2100, x: 2490)> Size: 10MB
# dask.array<open_rasterio-a14db4ab701fe823179eec7ae754de1c<this-array>, shape=(1, 2100, 2490), dtype=int16, chunksize=(1, 1024, 1024), chunktype=numpy.ndarray>
# Coordinates:
#   * band         (band) int64 8B 1
#     xc           (y, x) float64 42MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     yc           (y, x) float64 42MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     spatial_ref  int64 8B 0
# Dimensions without coordinates: y, x
# Attributes:
#     OperationalQualityFlagExplanation:  All requested inputs were used
#     AREA_OR_POINT:                      Area
#     scale_factor:                       1.0
#     add_offset:                         0.0

# %%
ds = rxr.open_rasterio(url, mask_and_scale=False, chunks={'x':1024, 'y':1024})
